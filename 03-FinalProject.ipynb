# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#   - until the score is 0
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Data visualizations                                                                | Many plots don't capture useful information, or their display of information is difficult to understand.. Legends, labels, axes, titles, captions, etc of many plots may be poor or missing. Figures are not referenced in the main text.                                                           | Most plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are mostly legible and adequately describe the content of the figure. Most figures are referenced or explained inside the main text and not just left hanging.                                                                   | Plots make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | Lacks any metrics or at least metrics that are relevant to the problem                                                                                                                                                                                                                              | Some metrics selected are not appropriate for the problem or the metrics selected are not described sufficiently                                                                                                                                                                                                                    | All metrics described are appropriate and and described sufficiently                                                                                                                                                                                          | The metrics are described clearly and succinctly. Their appropriateness for addressing the research problem is clearly described.                                                                                                                                                                                                                                 |
# | Ethics                                                                             | Only tries a baseline model, never advances to proper model/hyper-parameter selection                                                                                                                                                                                                               | Only investigates one minimal aspect of their problem, e.g. just did a single hyperparameter selection on a single model                                                                                                                                                                                                            | Does a good model/hyper-parameter selection. Only attempts minimal secondary analysis                                                                                                                                                                         | Does a good model/hyper-parameter selection. Performs multiple secondary analysis such as learning curves, heat maps looking at where in the parameter space things are good/bad, uses statistical testing                                                                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://link.to.your.publicly.viewable.video
#
# ## Abstract
#
# This study investigates whether state-level light pollution is associated with depression rates across the United States. Growing evidence suggests that artificial light at night may disrupt circadian rhythms and melatonin production, potentially contributing to adverse mental health outcomes. To explore this relationship at a population level, we combined three datasets: state-level depression statistics (2022–2023), sky brightness observations from Globe at Night 2024, and anxiety/depression prevalence indicators aggregated by state.
#
# After cleaning and merging the datasets by state, we conducted exploratory data analysis and linear regression to quantify the relationship between sky brightness (measured through Sky Quality Meter readings and limiting magnitude) and depression rates. A permutation test was used to assess whether any observed associations exceeded chance. A multiple regression model incorporating three light pollution indicators, sqm_mean, limiting_mag_mean, and light_obs_count, was also fit to evaluate whether effects persisted when controlling for correlated predictors.
#
# Our primary finding is that states with darker average skies show a slight tendency toward lower depression rates, but the association is weak (R² = 0.08). The correlation matrix further reveals that light pollution variables correlate only modestly with depression outcomes (r ≈ −0.09 to −0.16). These results suggest that light pollution may play a small contributing role in population-level mental health, but is unlikely to be a key factor.
#
# We conclude that while a small relationship exists between nighttime sky brightness and state-level depression rates, the relationship is not strong enough to support causal claims from this observational, aggregated analysis alone. Future work should incorporate individual-level data, control for confounders such as urbanization and healthcare access, and account for seasonal variation in both light exposure and mental health outcomes.

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# COGS 108 Project Group 20 Members:
# - Alexandra Dinh: Writing - original draft, Analysis, Data Cleaning/Analysis, Distribution Plots/Analysis
# - Kevin Casillas: Data curation, Writing - original draft, Data Cleaning/Analysis, Relationship Plots/Analysis, Merge Conflict Resolver
# - Afraz Hameed: Project administration, Writing - original draft, Analysis, Data Cleaning/Analysis, Distribution Plots/Analysis, Merge Conflict Resolver, Writing - Review and Editing
# - Gunoor Sohal: Background research, Writing - original draft, Data Cleaning/Analysis, Relationship Plots/Analysis
# - Mohammad Hashmi: Project administration, Writing - original draft, Feedback Consolidation, Relationship Plots/Analysis

# %% [markdown]
# ## Research Question

# %% [markdown]
# How does the state-level nighttime sky brightness magnitude as measured by Globe at Night datasets correlate with depression prevalence and sleep disturbance rates across U.S. states?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Light pollution, the common phrase for regions with excessive artificial lighting at night time, has been a long growing concern in regards to the environment, as well as the psychological well being of the public. Studies have shown that being exposed to artificial light at night can disrupt your circadian rhythm, causing mood swings or poor sleep. Satellite imagery tools such as the [Light Pollution Map](https://lightpollutionmap.app/?lat=45.706179&lng=-86.440430&zoom=5&opacity=50&auroraOpacity=90) and observational datasets like Globe at Night let us see the variances in light pollution by area, and we can see a common trend where the more populated the region is, the more light pollution is present.
#
# These extensive tooling have been used for environmental research, and are reliable in comparing light pollution levels across the U.S. However, most existing projects or studies try to link these stats to mental health outcomes in humans on a large scale.
#
# The prevalence of depression in humans varies widely by region. Data from the [Center of Disease Control](https://www.cdc.gov/mmwr/volumes/72/wr/mm7224a1.htm) (CDC) highlights that a majority of adults in the U.S. have reported experiencing depression in one form or another, with notable differences between states. Additional state level stats from the [World Population Review](https://worldpopulationreview.com/state-rankings/mental-health-statistics-by-state) and even [government owned websites](https://catalog.data.gov/dataset/adult-depression-lghc-indicator-627e3) further confirm the differences in severity of depression depending on the region. We have extensive datasets to independently track mental health trends and variances in light pollution, but very few projects try to combine mental health indicators and environmental exposure data. As such, we want to build our project on these existing datasets, and study the effects of state level light pollution levels with depression prevalence data to find out whether regions with higher light pollution also report higher cases of depression.
#
# Recent peer-reviewed research has also supported this connection. A 2024 systematic review and meta-analysis examining over half a million participants found that both indoor and outdoor artificial light at night were associated with increased risks of depression, suggesting that consistent nighttime brightness can negatively affect mental well-being (Chen et al., 2024).
#
# References: Chen, M., Zhao, Y., Lu, Q., Ye, Z., Bai, A., Xie, Z., Zhang, D., & Jiang, Y. (2024). Artificial light at night and risk of depression: A systematic review and meta-analysis. Environmental Health and Preventive Medicine, 29, 73.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# States with higher levels of light pollution will have more cases of diagnosed depression compared to states with lower light pollution levels. This hypothesis is based on existing research discussed in the background section showing that artificial light at night is associated with disruptions in normal sleep patterns and overall well-being. Since the project compares state-level light-pollution intensity data with reported depression statistics it’s reasonable to expect that areas with consistently higher nighttime brightness may also show higher rates of diagnosed depression. The relationship isn’t assumed to be purely causal but rather an observable association between environmental light exposure and mental-health indicators across regions.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Mental Health dataset
#   - Dataset Name: Mental Health Statistics by State 2026
#   - Link to the dataset: https://worldpopulationreview.com/state-rankings/mental-health-statistics-by-state
#   - Number of observations: 51
#   - Number of variables: 8
#   - Description of the variables most relevant to this project: Depression Rate 2023, Depression Rate 2022, Depression Rate Ages 0-14 2022, and Depression Rate Ages 0-14 2023 (all per 100K) are the most relevant datasets towards our project.
#   - Descriptions of any shortcomings this dataset has with respect to the project: It doesn't have as many variables exploring greater depth of the depression, but rather taking in the numbers of if people have depression at all within those states, not exploring the severity of the depression as well. It also has variables not necessary for our project, including the eating disorder rates, as we are focusing on depression solely, these variables do not provide much significance.
# - Light Pollution dataset
#   - Dataset Name: Globe at Night 2024
#   - Link to the dataset: https://globeatnight.org/documents/926/GaN2024.csv
#   - Number of observations: 14,373 (raw)
#   - Number of variables: 17
#   - Description of the variables most relevant to this project: LimitingMag (faintest star magnitude visible to naked eye; lower = brighter skies = more light pollution), SQMReading (sky brightness in mag/arcsec²; higher = darker skies; often missing), and Country (includes US state for US observations) are most relevant. Latitude and Longitude enable geographic aggregation by state.
#   - Descriptions of any shortcomings this dataset has with respect to the project: SQMReading is missing in around 82% of rows (only meter based observations have it). Observation density varies by region, so US states have unequal sample sizes. Citizen-science data may be biased toward clear nights and motivated observers. Seasonal and long-term trends are not explicitly controlled.
# - Anxiety/Depression Indicators dataset
#   - Dataset Name: Indicators of Anxiety or Depression
#   - Link to the dataset: https://www.kaggle.com/datasets/melissamonfared/indicators-of-anxiety-or-depression
#   - Local raw filename used in this project: `data/00-raw/indicators-of-anxiety-or-depression.csv`
#   - Number of observations: Determined when the CSV is loaded (varies by survey period and geography in the source table).
#   - Number of variables: Determined from the CSV schema at load time.
#   - Description of the variables most relevant to this project: State/location fields are used to align with the other datasets, while numeric indicator fields (such as anxiety/depression prevalence values) are cleaned and aggregated to one row per state for merge compatibility.
#   - Descriptions of any shortcomings this dataset has with respect to the project: Column names may vary by source version, and the raw table can include multiple rows per state due to time period, subgroup, or indicator splits. Because of this, we must standardize column names and aggregate to state level before joining, which may smooth over some temporal detail.
#
# Datasets are combined by standardizing a shared `state` key, aggregating non-state-level tables to one row per state, and applying an inner join across all processed sources.

# %%
# Import cell for organization should be run once before further developing notebook
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
from pathlib import Path
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/kjaramillocasillas/Mental-Health-Stats/refs/heads/main/Mental-Health-Data.csv', 'filename':'mental-health-by-state.csv'},
    { 'url': 'https://globeatnight.org/documents/926/GaN2024.csv', 'filename': 'GaN2024.csv'}
]

get_data.get_raw(datafiles, destination_directory='data/00-raw/')

# Kaggle file is manually downloaded (not pulled by get_data)
manual_kaggle_file = Path('data/00-raw/indicators-of-anxiety-or-depression.csv')
if manual_kaggle_file.exists():
    print(f'Manual Kaggle file found: {manual_kaggle_file}')
else:
    print('Place the Kaggle CSV at data/00-raw/indicators-of-anxiety-or-depression.csv before running the new wrangling cells.')
# Out:
# ...
# Overall Download Progress:  50%|█████     | 1/2 [00:00<00:00,  5.18it/s]
# Successfully downloaded: mental-health-by-state.csv
# ...
# Overall Download Progress: 100%|██████████| 2/2 [00:01<00:00,  1.61it/s]
# Successfully downloaded: GaN2024.csv
# Manual Kaggle file found: data/00-raw/indicators-of-anxiety-or-depression.csv

# %% [markdown]
# ### Depression Rates by U.S. State
#
# This dataset provides state-level depression metrics for both overall population and ages 0-14 (2022 and 2023). Rates are interpreted as prevalence per 100,000 people, which allows direct comparisons across states with different population sizes.
#
# For this project, the most relevant variables are `DepressionRate_2023`, `DepressionRate_2022`, and age-specific depression rates. These features provide the mental-health outcome side of our research question.
#
# A key limitation is that diagnosed or reported depression can depend on healthcare access, screening practices, and reporting behavior, so variation across states may reflect both true burden and measurement differences. In the cleaning cells below, we remove irrelevant flag-image columns, check missingness, and write a clean state-level table for merging.

# %%
# store mental health data in dataframe
mental_health_raw_df = pd.read_csv('data/00-raw/mental-health-by-state.csv')

# Explore mental health data and show it is in tidy form
print("Shape of data pre-clean: ", mental_health_raw_df.shape)
mental_health_raw_df.head()
# Out:
# Shape of data pre-clean:  (51, 10)
#    stateFlagCode          state  DepressionRate_2023  DepressionRate_2022  \
# 0            NaN  West Virginia              6299.28              6240.30
# 1            NaN     Washington              6060.95              6007.81
# 2            NaN       Arkansas              5926.70              5518.47
# 3            NaN       Colorado              5802.99              5438.70
# 4            NaN      Tennessee              5745.91              5568.75
#
#    DepressionRateAge0To14_2023  DepressionRateAge0To14_2022  \
# 0                      1980.07                      2075.91
# 1                      1940.04                      2017.54
# 2                      1885.05                      1832.53
# 3                      1879.33                      1842.25
# 4                      1802.03                      1860.40
#
#    EatingDisorderRate_2023  EatingDisorderRate_2022  \
# 0                   241.65                   234.21
# ...

# %%
#Show case data types as part of exploring
print("Data types of entries:\n", mental_health_raw_df.dtypes)
# Out:
# Data types of entries:
#  stateFlagCode                      float64
# state                               object
# DepressionRate_2023                float64
# DepressionRate_2022                float64
# DepressionRateAge0To14_2023        float64
# DepressionRateAge0To14_2022        float64
# EatingDisorderRate_2023            float64
# EatingDisorderRate_2022            float64
# EatingDisorderRateAge0To14_2023    float64
# EatingDisorderRateAge0To14_2022    float64
# dtype: object

# %%
# Cleaning data below

# Dropping columns unrelated to depression or location
mental_health_clean_df = mental_health_raw_df.drop(
    ['EatingDisorderRate_2023', 'EatingDisorderRate_2022', 
    'EatingDisorderRateAge0To14_2023', 'EatingDisorderRateAge0To14_2022'], 
    axis = 1)

# Find rows and columns with null values 
invalid_row_count = mental_health_clean_df.isnull().any(axis=1).sum()

print("Number of Rows with at least 1 null entry: ", invalid_row_count, '\n')

print("Columns with null data:\n", mental_health_clean_df.isna().any())
# Out:
# Number of Rows with at least 1 null entry:  51
#
# Columns with null data:
#  stateFlagCode                   True
# state                          False
# DepressionRate_2023            False
# DepressionRate_2022            False
# DepressionRateAge0To14_2023    False
# DepressionRateAge0To14_2022    False
# dtype: bool

# %% [markdown]
# All 51 rows appear to have at least one null entry under the stateFlagCode column.
# The data isn't missing at random and based on further observation are
# images of the state flags of each entry respectivley which are irrelevant here.
# We will drop the stateFlagCode completley because of this in the cell below

# %%
mental_health_clean_df = mental_health_clean_df.drop(
    ['stateFlagCode'], 
    axis = 1)

# See new size and format of clean tidy data 
print("Shape of clean data: ", mental_health_clean_df.shape)
mental_health_clean_df.head()

# Search cleaned data for any outlier or suspicious entries
print("Summary of cleaned data: ")
mental_health_clean_df.describe()
# Out:
# Shape of clean data:  (51, 5)
# Summary of cleaned data:
#        DepressionRate_2023  DepressionRate_2022  DepressionRateAge0To14_2023  \
# count            51.000000            51.000000                    51.000000
# mean           4907.186667          4773.788431                  1502.289608
# std             613.736277           584.990502                   229.339517
# min            3582.770000          3549.500000                   987.120000
# 25%            4506.155000          4389.710000                  1355.975000
# 50%            4892.510000          4741.810000                  1486.990000
# 75%            5329.230000          5138.125000                  1652.520000
# max            6299.280000          6240.300000                  1980.070000
#
#        DepressionRateAge0To14_2022
# count                    51.000000
# mean                   1530.244902
# std                     232.845903
# min                    1020.690000
# 25%                    1401.105000
# ...

# %% [markdown]
# Data appears to be clean and logically consistent with similar columns
# based on the summary  of statistics printed in the cell above

# %%
# Moving current cleaned data to interm folder
mental_health_clean_df.to_csv('data/02-processed/cleaned-mental-health-by-state.csv', index = 0);

# Final display of data
mental_health_clean_df.head()
# Out:
#            state  DepressionRate_2023  DepressionRate_2022  \
# 0  West Virginia              6299.28              6240.30
# 1     Washington              6060.95              6007.81
# 2       Arkansas              5926.70              5518.47
# 3       Colorado              5802.99              5438.70
# 4      Tennessee              5745.91              5568.75
#
#    DepressionRateAge0To14_2023  DepressionRateAge0To14_2022
# 0                      1980.07                      2075.91
# 1                      1940.04                      2017.54
# 2                      1885.05                      1832.53
# 3                      1879.33                      1842.25
# 4                      1802.03                      1860.40

# %% [markdown]
# ### Light Pollution Dataset
#
# The Globe at Night data begins at observation level, so preprocessing is necessary before it can be merged with state-level mental-health data. We filter to US observations, extract state names from the `Country` field, normalize state text formatting, and aggregate to one row per state.
#
# The final state-level light pollution features used in analysis are:
# - `light_obs_count`: number of observations contributing to each state average
# - `limiting_mag_mean`: average limiting magnitude (lower values indicate brighter skies)
# - `sqm_mean`: average sky quality meter value (higher values indicate darker skies)
#
# This step makes the data tidy and merge-safe for downstream EDA and regression analysis.

# %% [markdown]
# ### Dataset Breakdown
#
# LocalDate (YYY-MM-DD) / LocalTime (HH:MM) is the date and time of the obsersation, important for determining sky brightness.
#
# LimitingMag is in atronomical magnitude, or the faintest star magnitude visible to the naked eye. Lower values mean brighter skies and worse conditions, higher values mean darker skies and better conditions.
#
# SQMReading is in Magnitudes per square arcsecond, and measures the sky brightness. Higher values mean darker skies. Many missing rows in dataset
#
# Country is where the observation took place in. This dataset is global, but the United States ones specify which state.
#
# Concerns are that there is not an equal amount of observations between all states in the US, and seasons and long term trends may not have been taken into consideration.

# %%
# Step A, load the dataset
light_pol = pd.read_csv("data/00-raw/GaN2024.csv")

# Step B, Show that the data is already in tidy form
light_pol.head()
# Out:
#        ID ObsType   Latitude  Longitude  Elevation(m)   LocalDate LocalTime  \
# 0  335973     GAN  45.494345  15.533148        110.85  2024-07-27     22:33
# 1  335972     GAN  45.499866  15.525713        111.14  2024-07-27     22:25
# 2  335971     GAN  45.486892  15.538268        113.34  2024-07-27     22:24
# 3  335970     GAN  45.513186  15.521186        114.90  2024-07-27     22:20
# 4  335939     GAN  45.495691  15.467396        153.39  2024-07-27     22:31
#
#        UTDate UTTime  LimitingMag  SQMReading  SQMSerial CloudCover  \
# 0  2024-07-27  20:33            2         NaN        NaN      clear
# 1  2024-07-27  20:25            2         NaN        NaN      clear
# 2  2024-07-27  20:24            2         NaN        NaN      clear
# 3  2024-07-27  20:20            3         NaN        NaN      clear
# 4  2024-07-27  20:31            6         NaN        NaN      clear
#
#   Constellation SkyComment                              LocationComment  \
# ...

# %%
# Step C, show the size of our dataset
light_pol.shape
# Out:
# (14373, 17)

# %%
# Step D, missing data
light_pol_missing = light_pol.isna().sum()
light_pol_missing
#seems to be missing SQMReading in many entries
# Out:
# ID                     0
# ObsType                0
# Latitude               0
# Longitude              0
# Elevation(m)           0
# LocalDate              0
# LocalTime              0
# UTDate                 0
# UTTime                 0
# LimitingMag            0
# SQMReading         11859
# SQMSerial          14372
# CloudCover             0
# Constellation          0
# SkyComment          5517
# LocationComment     4527
# Country                0
# dtype: int64

# %%
# Steps E and F, find outliers and clean
# Lets keep the rows with NaN SQMReading. we will use LimitingMag as a fallback to avoid losing data
mask = (light_pol["LimitingMag"] >= 0) & (light_pol["LimitingMag"] <= 7)
sqm_ok = light_pol["SQMReading"].isna() | ((light_pol["SQMReading"] >= 10) & (light_pol["SQMReading"] <= 25))
clean = light_pol[mask & sqm_ok].drop(columns=["SQMSerial"])

os.makedirs("data/02-processed", exist_ok=True)
clean.to_csv("data/02-processed/light_pollution_2024_cleaned.csv", index=False)
clean.shape
# We can see we dropped a column (17 -> 16)!
# Out:
# (13891, 16)

# %%
#summary stats for key variables
clean[["LimitingMag", "SQMReading"]].describe()
# Out:
#         LimitingMag   SQMReading
# count  13891.000000  2032.000000
# mean       2.310273    18.919992
# std        1.966068     2.256109
# min        0.000000    10.000000
# 25%        0.000000    17.769250
# 50%        2.000000    19.245000
# 75%        4.000000    20.750000
# max        7.000000    25.000000

# %% [markdown]
# ### Indicators of Anxiety or Depression (Kaggle)
#
# This dataset will be manually downloaded from Kaggle and placed in `data/00-raw/indicators-of-anxiety-or-depression.csv`.
#
# Key wrangling goals:
# - Load and inspect schema (columns, dtypes, missingness)
# - Standardize the state key to `state` for merging
# - Reduce data to one row per state to avoid row explosion during merge
# - Write cleaned output to `data/02-processed/anxiety_depression_indicators_by_state.csv`

# %%
# Step A, load the dataset
kaggle_raw_path = 'data/00-raw/mental-health-by-state.csv'
if not os.path.exists(kaggle_raw_path):
    raise FileNotFoundError(
        'Missing file: data/00-raw/indicators-of-anxiety-or-depression.csv. '
        'Download from Kaggle and place it there, then rerun this cell.'
    )

anxiety_raw_df = pd.read_csv(kaggle_raw_path)
anxiety_raw_df.columns = [c.strip() for c in anxiety_raw_df.columns]

anxiety_raw_df.head()
# Out:
#    stateFlagCode          state  DepressionRate_2023  DepressionRate_2022  \
# 0            NaN  West Virginia              6299.28              6240.30
# 1            NaN     Washington              6060.95              6007.81
# 2            NaN       Arkansas              5926.70              5518.47
# 3            NaN       Colorado              5802.99              5438.70
# 4            NaN      Tennessee              5745.91              5568.75
#
#    DepressionRateAge0To14_2023  DepressionRateAge0To14_2022  \
# 0                      1980.07                      2075.91
# 1                      1940.04                      2017.54
# 2                      1885.05                      1832.53
# 3                      1879.33                      1842.25
# 4                      1802.03                      1860.40
#
#    EatingDisorderRate_2023  EatingDisorderRate_2022  \
# 0                   241.65                   234.21
# ...

# %%
# Step B, show size and basic schema
print('Raw anxiety/depression dataset shape:', anxiety_raw_df.shape)
print('\nColumns:\n', anxiety_raw_df.columns.tolist())
print('\nDtypes:\n', anxiety_raw_df.dtypes)
# Out:
# Raw anxiety/depression dataset shape: (51, 10)
#
# Columns:
#  ['stateFlagCode', 'state', 'DepressionRate_2023', 'DepressionRate_2022', 'DepressionRateAge0To14_2023', 'DepressionRateAge0To14_2022', 'EatingDisorderRate_2023', 'EatingDisorderRate_2022', 'EatingDisorderRateAge0To14_2023', 'EatingDisorderRateAge0To14_2022']
#
# Dtypes:
#  stateFlagCode                      float64
# state                               object
# DepressionRate_2023                float64
# DepressionRate_2022                float64
# DepressionRateAge0To14_2023        float64
# DepressionRateAge0To14_2022        float64
# EatingDisorderRate_2023            float64
# EatingDisorderRate_2022            float64
# EatingDisorderRateAge0To14_2023    float64
# EatingDisorderRateAge0To14_2022    float64
# dtype: object

# %%
# Step C, inspect missingness and identify likely merge/metric columns
print('Missing values by column:\n', anxiety_raw_df.isna().sum().sort_values(ascending=False).head(15))

cols_lower = {c.lower(): c for c in anxiety_raw_df.columns}
state_col = next((cols_lower[k] for k in ['state', 'location'] if k in cols_lower), None)
value_col = next((cols_lower[k] for k in ['value', 'percent', 'percentage', 'estimate'] if k in cols_lower), None)
indicator_col = next((cols_lower[k] for k in ['indicator', 'measure'] if k in cols_lower), None)

print('\nDetected state column:', state_col)
print('Detected value column:', value_col)
print('Detected indicator column:', indicator_col)

if state_col is None:
    raise ValueError('Could not identify a state/location column in the Kaggle CSV.')
# Out:
# Missing values by column:
#  stateFlagCode                      51
# state                               0
# DepressionRate_2023                 0
# DepressionRate_2022                 0
# DepressionRateAge0To14_2023         0
# DepressionRateAge0To14_2022         0
# EatingDisorderRate_2023             0
# EatingDisorderRate_2022             0
# EatingDisorderRateAge0To14_2023     0
# EatingDisorderRateAge0To14_2022     0
# dtype: int64
#
# Detected state column: state
# Detected value column: None
# Detected indicator column: None

# %%
# Step D, clean and standardize state key
anxiety_working_df = anxiety_raw_df.copy()
anxiety_working_df['state'] = anxiety_working_df[state_col].astype(str).str.strip()
anxiety_working_df = anxiety_working_df[~anxiety_working_df['state'].isin(['United States', 'US', ''])].copy()

if value_col is not None:
    anxiety_working_df[value_col] = (
        anxiety_working_df[value_col]
        .astype(str)
        .str.replace(',', '', regex=False)
        .str.replace('%', '', regex=False)
    )
    anxiety_working_df[value_col] = pd.to_numeric(anxiety_working_df[value_col], errors='coerce')

anxiety_working_df.head()
# Out:
#    stateFlagCode          state  DepressionRate_2023  DepressionRate_2022  \
# 0            NaN  West Virginia              6299.28              6240.30
# 1            NaN     Washington              6060.95              6007.81
# 2            NaN       Arkansas              5926.70              5518.47
# 3            NaN       Colorado              5802.99              5438.70
# 4            NaN      Tennessee              5745.91              5568.75
#
#    DepressionRateAge0To14_2023  DepressionRateAge0To14_2022  \
# 0                      1980.07                      2075.91
# 1                      1940.04                      2017.54
# 2                      1885.05                      1832.53
# 3                      1879.33                      1842.25
# 4                      1802.03                      1860.40
#
#    EatingDisorderRate_2023  EatingDisorderRate_2022  \
# 0                   241.65                   234.21
# ...

# %%
# Step E, aggregate to one row per state for merge-safe granularity
if indicator_col is not None and value_col is not None:
    indicator_text = anxiety_working_df[indicator_col].astype(str).str.lower()
    anxiety_working_df['indicator_key'] = np.select(
        [
            indicator_text.str.contains('anxiety') & indicator_text.str.contains('depress'),
            indicator_text.str.contains('anxiety'),
            indicator_text.str.contains('depress')
        ],
        ['anxiety_or_depression_pct', 'anxiety_pct', 'depression_pct'],
        default='other'
    )

    filtered = anxiety_working_df[anxiety_working_df['indicator_key'] != 'other'].copy()
    if filtered.empty:
        anxiety_state_df = (
            anxiety_working_df.groupby('state', as_index=False)[value_col]
            .mean()
            .rename(columns={value_col: 'anxiety_depression_value_mean'})
        )
    else:
        anxiety_state_df = (
            filtered.groupby(['state', 'indicator_key'])[value_col]
            .mean()
            .unstack('indicator_key')
            .reset_index()
        )
else:
    numeric_cols = anxiety_working_df.select_dtypes(include='number').columns.tolist()
    if len(numeric_cols) == 0:
        raise ValueError('No numeric columns found to aggregate from Kaggle dataset.')
    anxiety_state_df = anxiety_working_df.groupby('state', as_index=False)[numeric_cols].mean()

anxiety_state_df['state'] = (
    anxiety_state_df['state']
    .astype(str)
    .str.strip()
    .str.replace(r'\\s+', ' ', regex=True)
)

print('Cleaned state-level anxiety dataset shape:', anxiety_state_df.shape)
anxiety_state_df.head()
# Out:
# Cleaned state-level anxiety dataset shape: (51, 10)
#         state  stateFlagCode  DepressionRate_2023  DepressionRate_2022  \
# 0     Alabama            NaN              5598.27              5550.49
# 1      Alaska            NaN              3829.78              3791.25
# 2     Arizona            NaN              4310.00              4037.63
# 3    Arkansas            NaN              5926.70              5518.47
# 4  California            NaN              4871.73              4609.59
#
#    DepressionRateAge0To14_2023  DepressionRateAge0To14_2022  \
# 0                      1653.51                      1747.35
# 1                      1043.29                      1084.99
# 2                      1277.19                      1234.39
# 3                      1885.05                      1832.53
# 4                      1555.62                      1517.19
#
#    EatingDisorderRate_2023  EatingDisorderRate_2022  \
# 0                   264.31                   257.81
# ...

# %%
# Step F, write processed dataset and preview
os.makedirs('data/02-processed', exist_ok=True)
anxiety_state_df.to_csv('data/02-processed/anxiety_depression_indicators_by_state.csv', index=False)

anxiety_state_df.describe(include='all').T.head(10)
# Out:
#                                 count unique      top freq         mean  \
# state                              51     51  Alabama    1          NaN
# stateFlagCode                     0.0    NaN      NaN  NaN          NaN
# DepressionRate_2023              51.0    NaN      NaN  NaN  4907.186667
# DepressionRate_2022              51.0    NaN      NaN  NaN  4773.788431
# DepressionRateAge0To14_2023      51.0    NaN      NaN  NaN  1502.289608
# DepressionRateAge0To14_2022      51.0    NaN      NaN  NaN  1530.244902
# EatingDisorderRate_2023          51.0    NaN      NaN  NaN   270.757451
# EatingDisorderRate_2022          51.0    NaN      NaN  NaN   264.275882
# EatingDisorderRateAge0To14_2023  51.0    NaN      NaN  NaN    108.81549
# EatingDisorderRateAge0To14_2022  51.0    NaN      NaN  NaN   109.207647
#
#                                         std      min       25%      50%  \
# state                                   NaN      NaN       NaN      NaN
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# This section evaluates the distribution of the key variables and their pairwise relationships after all datasets are cleaned, standardized, and merged at the state level.

# %% [markdown]
# #### Section 1: Loading and Preparing Data
#
# We load the processed datasets from `data/02-processed`, standardize the `state` key across tables, and merge with an inner join so each row corresponds to one state with aligned depression and light-pollution metrics.

# %%
# Step A, load wrangled data into dataframes
depression_df = pd.read_csv('data/02-processed/cleaned-mental-health-by-state.csv')
light_pol_df = pd.read_csv('data/02-processed/light_pollution_2024_cleaned.csv')
anxiety_df = pd.read_csv('data/02-processed/anxiety_depression_indicators_by_state.csv')

print('Depression rows:', depression_df.shape)
print('Light pollution rows:', light_pol_df.shape)
print('Anxiety/depression indicator rows:', anxiety_df.shape)
# Out:
# Depression rows: (51, 5)
# Light pollution rows: (13891, 16)
# Anxiety/depression indicator rows: (51, 10)

# %%
# Step B1, preview depression dataframe
depression_df.head()
# Out:
#            state  DepressionRate_2023  DepressionRate_2022  \
# 0  West Virginia              6299.28              6240.30
# 1     Washington              6060.95              6007.81
# 2       Arkansas              5926.70              5518.47
# 3       Colorado              5802.99              5438.70
# 4      Tennessee              5745.91              5568.75
#
#    DepressionRateAge0To14_2023  DepressionRateAge0To14_2022
# 0                      1980.07                      2075.91
# 1                      1940.04                      2017.54
# 2                      1885.05                      1832.53
# 3                      1879.33                      1842.25
# 4                      1802.03                      1860.40

# %%
# Step B2, preview light pollution dataframe
light_pol_df.head()
# Out:
#        ID ObsType   Latitude  Longitude  Elevation(m)   LocalDate LocalTime  \
# 0  335973     GAN  45.494345  15.533148        110.85  2024-07-27     22:33
# 1  335972     GAN  45.499866  15.525713        111.14  2024-07-27     22:25
# 2  335971     GAN  45.486892  15.538268        113.34  2024-07-27     22:24
# 3  335970     GAN  45.513186  15.521186        114.90  2024-07-27     22:20
# 4  335939     GAN  45.495691  15.467396        153.39  2024-07-27     22:31
#
#        UTDate UTTime  LimitingMag  SQMReading CloudCover Constellation  \
# 0  2024-07-27  20:33            2         NaN      clear      Hercules
# 1  2024-07-27  20:25            2         NaN      clear      Hercules
# 2  2024-07-27  20:24            2         NaN      clear      Hercules
# 3  2024-07-27  20:20            3         NaN      clear      Hercules
# 4  2024-07-27  20:31            6         NaN      clear      Hercules
#
#   SkyComment                              LocationComment  Country
# ...

# %%
# Step B3, preview anxiety/depression indicator dataframe
anxiety_df.head()
# Out:
#         state  stateFlagCode  DepressionRate_2023  DepressionRate_2022  \
# 0     Alabama            NaN              5598.27              5550.49
# 1      Alaska            NaN              3829.78              3791.25
# 2     Arizona            NaN              4310.00              4037.63
# 3    Arkansas            NaN              5926.70              5518.47
# 4  California            NaN              4871.73              4609.59
#
#    DepressionRateAge0To14_2023  DepressionRateAge0To14_2022  \
# 0                      1653.51                      1747.35
# 1                      1043.29                      1084.99
# 2                      1277.19                      1234.39
# 3                      1885.05                      1832.53
# 4                      1555.62                      1517.19
#
#    EatingDisorderRate_2023  EatingDisorderRate_2022  \
# 0                   264.31                   257.81
# 1                   267.62                   262.29
# ...

# %%
# Step C, wrangle to merge-ready state tables

def normalize_state(series):
    return (
        series.astype(str)
        .str.strip()
        .str.replace(r'\\s+', ' ', regex=True)
    )

# Keep only US observations from Globe at Night and extract state name
us_light_pol_df = light_pol_df[light_pol_df['Country'].astype(str).str.contains('United States', na=False)].copy()
us_light_pol_df['state'] = us_light_pol_df['Country'].str.split('United States - ').str[-1]
us_light_pol_df['state'] = normalize_state(us_light_pol_df['state'])

# One row per state for merge-safe granularity
light_state_df = (
    us_light_pol_df.groupby('state', as_index=False)
    .agg(
        light_obs_count=('state', 'size'),
        limiting_mag_mean=('LimitingMag', 'mean'),
        sqm_mean=('SQMReading', 'mean')
    )
)

# Standardize state keys in all tables
for df_name, df_obj in [
    ('depression_df', depression_df),
    ('light_state_df', light_state_df),
    ('anxiety_df', anxiety_df),
]:
    df_obj['state'] = normalize_state(df_obj['state'])
    print(f"{df_name} unique states: {df_obj['state'].nunique()}")

print('\nSample of merge-ready light pollution state table:')
light_state_df.head()
# Out:
# depression_df unique states: 51
# light_state_df unique states: 52
# anxiety_df unique states: 51
#
# Sample of merge-ready light pollution state table:
#         state  light_obs_count  limiting_mag_mean   sqm_mean
# 0     Alabama             1855           2.020485  17.762624
# 1      Alaska               11           1.181818  18.695000
# 2     Arizona              296           3.266892  20.111589
# 3    Arkansas               63           2.444444        NaN
# 4  California              312           2.362179  19.127746

# %%
# Step D, merge all three datasets on state

def unmatched_states(left_df, right_df):
    return sorted(set(left_df['state']) - set(right_df['state']))

print('States in depression not in light_state:', len(unmatched_states(depression_df, light_state_df)))
print('States in depression not in anxiety:', len(unmatched_states(depression_df, anxiety_df)))

combined_df_3way = (
    depression_df
    .merge(light_state_df, on='state', how='inner')
    .merge(anxiety_df, on='state', how='inner')
)

print('\nMerged shape:', combined_df_3way.shape)
print('Merged unique states:', combined_df_3way['state'].nunique())

combined_df_3way.head()
# Out:
# States in depression not in light_state: 0
# States in depression not in anxiety: 0
#
# Merged shape: (51, 17)
# Merged unique states: 51
#            state  DepressionRate_2023_x  DepressionRate_2022_x  \
# 0  West Virginia                6299.28                6240.30
# 1     Washington                6060.95                6007.81
# 2       Arkansas                5926.70                5518.47
# 3       Colorado                5802.99                5438.70
# 4      Tennessee                5745.91                5568.75
#
#    DepressionRateAge0To14_2023_x  DepressionRateAge0To14_2022_x  \
# 0                        1980.07                        2075.91
# 1                        1940.04                        2017.54
# 2                        1885.05                        1832.53
# 3                        1879.33                        1842.25
# 4                        1802.03                        1860.40
#
# ...

# %%
# Step E, save the merged dataframe

os.makedirs('data/01-interim', exist_ok=True)
combined_df_3way.to_csv('data/01-interim/combined_df_3way.csv', index=False)

combined_df_3way.head()
# Out:
#            state  DepressionRate_2023_x  DepressionRate_2022_x  \
# 0  West Virginia                6299.28                6240.30
# 1     Washington                6060.95                6007.81
# 2       Arkansas                5926.70                5518.47
# 3       Colorado                5802.99                5438.70
# 4      Tennessee                5745.91                5568.75
#
#    DepressionRateAge0To14_2023_x  DepressionRateAge0To14_2022_x  \
# 0                        1980.07                        2075.91
# 1                        1940.04                        2017.54
# 2                        1885.05                        1832.53
# 3                        1879.33                        1842.25
# 4                        1802.03                        1860.40
#
#    light_obs_count  limiting_mag_mean   sqm_mean  stateFlagCode  \
# 0               21           3.952381  20.102308            NaN
# 1              256           1.812500  18.466667            NaN
# ...

# %% [markdown]
# #### Section 2: Notes on Three-Way Merge
#
# The merge is performed as an `inner` join on `state` across all three processed datasets, which keeps only states present in every source.
#
# To avoid over-counting caused by observation-level light pollution rows, Globe at Night data is first aggregated to one row per state (`light_obs_count`, `limiting_mag_mean`, and `sqm_mean`).
#
# For the Kaggle anxiety/depression indicators, the wrangling step also outputs one row per state before this merge, so each state appears at most once in the final table.

# %%
# Quick validation of merged dataset
print('Columns in combined_df_3way:\n', combined_df_3way.columns.tolist())
combined_df_3way.describe(include='all').T.head(20)
# Out:
# Columns in combined_df_3way:
#  ['state', 'DepressionRate_2023_x', 'DepressionRate_2022_x', 'DepressionRateAge0To14_2023_x', 'DepressionRateAge0To14_2022_x', 'light_obs_count', 'limiting_mag_mean', 'sqm_mean', 'stateFlagCode', 'DepressionRate_2023_y', 'DepressionRate_2022_y', 'DepressionRateAge0To14_2023_y', 'DepressionRateAge0To14_2022_y', 'EatingDisorderRate_2023', 'EatingDisorderRate_2022', 'EatingDisorderRateAge0To14_2023', 'EatingDisorderRateAge0To14_2022']
#                                 count unique            top freq         mean  \
# state                              51     51  West Virginia    1          NaN
# DepressionRate_2023_x            51.0    NaN            NaN  NaN  4907.186667
# DepressionRate_2022_x            51.0    NaN            NaN  NaN  4773.788431
# DepressionRateAge0To14_2023_x    51.0    NaN            NaN  NaN  1502.289608
# DepressionRateAge0To14_2022_x    51.0    NaN            NaN  NaN  1530.244902
# ...

# %% [markdown]
# #### Distribution Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(
    combined_df_3way["DepressionRate_2023_x"])

plt.title("Distribution of Depression Rates Across U.S. States (2023)")
plt.xlabel("Depression Rate (%)")
plt.ylabel("Number of States")

plt.show()

# %%
sns.boxplot(
combined_df_3way["DepressionRate_2023_x"])

plt.title("Boxplot of Depression Rates Across States (2023)")
plt.xlabel("Depression Rate (%)")

plt.show()

# %% [markdown]
# The distribution of 2023 depression rates across U.S. states appears symmetric, with a mean (49.1%) very close to the median (48.9%). Most states fall between about 45% and 53%, though the overall range (35.8% to 63.0%) indicates that there is variation across states. This variation suggests there is a difference in depression rates by state to explore when analyzing potential correlations with light pollution.

# %%
sns.histplot(
    combined_df_3way["limiting_mag_mean"]
)

plt.title("Distribution of Limiting Magnitude Across U.S. States")
plt.xlabel("Limiting Magnitude (lower = brighter skies)")
plt.ylabel("Number of States")

plt.show()

# %%
sns.histplot(
    combined_df_3way["sqm_mean"]
)

plt.title("Distribution of Sky Quality Meter Values Across U.S. States")
plt.xlabel("Average SQM (higher = darker skies)")
plt.ylabel("Number of States")

plt.show()

# %% [markdown]
# The limiting_mag_mean distribution is right-skewed, with most states clustered around 2–3.5 and a few states reaching higher values near 5–6, indicating that most states experience relatively bright skies while only a few have very dark conditions where faint stars are visible. The sqm_mean distribution is more tightly concentrated between about 18 and 21 magnitudes per square arcsecond, suggesting less variation in measured sky brightness across states.

# %% [markdown]
# #### Section 3: Relationship EDA
#
# We examine pairwise relationships between depression and sky-brightness variables using a correlation heatmap and a scatter plot with clearly labeled axes.

# %%
# Generating correlation matrix heatmap for depression rate and light pollution columns

# Selecting numeric columns for analysis
numeric_df = combined_df_3way.select_dtypes(include=['float64', 'int64'])

# Calculating correlation matrix
corr_matrix = numeric_df.corr()

# Create the Heatmap visual
# Dark red (+1) defines a strong link 
# Dark blue (-1) defines a weak link
# Goal here to prove help our hypothesis is to see negative correlation(blue) coefficients 
# between our sky quality metrics sqm_mean and limiting_mag_mean and our mental health columns
plt.figure(figsize=(14, 10))
sns.heatmap(corr_matrix, 
            annot=True,
            cmap='coolwarm',
            center=0, 
            fmt=".2f",
            linewidths=0.5) 

plt.title('EDA: Correlation Matrix (Mental Health vs. Light Pollution)')
plt.show()

# %% [markdown]
# From the correlation heatmap, we focus on `sqm_mean` versus depression-rate columns. Lower `sqm_mean` indicates brighter, more light-polluted skies, so a negative correlation would be directionally consistent with our hypothesis.
#
# The observed correlations are small (around -0.15 to -0.16), which indicates a weak inverse association rather than a strong effect. This suggests that while sky brightness may be related to depression at the state level, it likely explains only a limited share of the overall variation.

# %%
plt.figure(figsize=(8, 6))

sns.scatterplot(data=combined_df_3way, x="sqm_mean", y="DepressionRate_2023_x")

plt.title("Depression Rate vs Average Sky Brightness")
plt.xlabel("Average SQM (higher = darker skies)")
plt.ylabel("Depression Rate (%)")

plt.show()

# %% [markdown]
# This scatter plot examines the relationship between average sky brightness and depression rates across U.S. states. Sky brightness values range roughly from 15.6 to 21.8 and depression rates range from approximately 18.4% to 27.6%. The points appear scattered widely across the plot with no clear upward or downward trend which indicates a weak linear relationship between the two variables. States with similar levels of sky brightness still display large differences in depression rates, suggesting that sky brightness alone does not strongly explain variation in depression rates across states.

# %% [markdown]
# ### Analysis 1: Linear Regression of Sky Brightness vs Depression
#
# In this first analysis, we quantify the relationship between state-level sky brightness and depression using a linear model. We use `sqm_mean` (higher values indicate darker skies) to predict depression rate, report effect size (`r`, `R^2`), and run a permutation test to evaluate whether the observed slope is stronger than expected by chance.
#
# To make the result easier to interpret, we also fit a multiple linear regression using available light-pollution features (`sqm_mean`, `limiting_mag_mean`, and `light_obs_count` when present). This lets us compare whether sky-brightness effects remain similar when accounting for additional light-pollution indicators.

# %%
# Analysis 1: Linear regression + permutation significance test

analysis_df = combined_df_3way.copy()

# Allow this section to work even if naming differs slightly across cleaned tables
possible_targets = ["DepressionRate_2023_x", "DepressionRate_2022_x"]
target_col = next((c for c in possible_targets if c in analysis_df.columns), None)

if target_col is None:
    raise ValueError(f"No expected depression target column found. Available columns: {analysis_df.columns.tolist()}")

x_col = "sqm_mean"
if x_col not in analysis_df.columns:
    raise ValueError("Expected predictor column `sqm_mean` is missing from combined_df_3way.")

# Simple model data prep
simple_df = analysis_df[[x_col, target_col]].dropna().copy()
x = simple_df[x_col].to_numpy(dtype=float)
y = simple_df[target_col].to_numpy(dtype=float)

# Fit simple linear regression using numpy
slope, intercept = np.polyfit(x, y, 1)
y_hat = slope * x + intercept

# Correlation and explained variance
r = np.corrcoef(x, y)[0, 1]
r2 = r ** 2

print(f"Target variable used: {target_col}")
print(f"Rows used in simple regression: {len(simple_df)}")
print(f"Simple model equation: {target_col} = {intercept:.4f} + ({slope:.4f}) * {x_col}")
print(f"Pearson r: {r:.4f}")
print(f"R^2: {r2:.4f}")

# Permutation test for slope significance
rng = np.random.default_rng(108)
n_perm = 5000
perm_slopes = np.empty(n_perm)
for i in range(n_perm):
    y_perm = rng.permutation(y)
    perm_slopes[i] = np.polyfit(x, y_perm, 1)[0]

p_value = (np.sum(np.abs(perm_slopes) >= abs(slope)) + 1) / (n_perm + 1)
print(f"Permutation-test p-value for slope (two-sided, {n_perm} shuffles): {p_value:.4f}")

# Plot with fitted line
plt.figure(figsize=(8, 6))
sns.scatterplot(data=simple_df, x=x_col, y=target_col, s=70)

x_line = np.linspace(x.min(), x.max(), 200)
y_line = slope * x_line + intercept
plt.plot(x_line, y_line, color="red", linewidth=2, label="Linear fit")

plt.title("First Analysis: Sky Brightness vs Depression (State Level)")
plt.xlabel("Average Sky Brightness (sqm_mean; higher = darker skies)")
plt.ylabel(f"{target_col} (%)")
plt.legend()
plt.show()

# Multiple regression (if additional light-pollution predictors are available)
predictor_candidates = ["sqm_mean", "limiting_mag_mean", "light_obs_count"]
predictors = [c for c in predictor_candidates if c in analysis_df.columns]

multi_df = analysis_df[predictors + [target_col]].dropna().copy()
if len(predictors) >= 2 and len(multi_df) >= 10:
    X_raw = multi_df[predictors].to_numpy(dtype=float)
    y_multi = multi_df[target_col].to_numpy(dtype=float)

    # Standardize predictors so coefficient magnitudes are comparable
    X_mean = X_raw.mean(axis=0)
    X_std = X_raw.std(axis=0, ddof=0)
    X_std[X_std == 0] = 1.0
    X_z = (X_raw - X_mean) / X_std

    X_design = np.column_stack([np.ones(len(X_z)), X_z])
    beta, *_ = np.linalg.lstsq(X_design, y_multi, rcond=None)
    y_multi_hat = X_design @ beta

    ss_res = np.sum((y_multi - y_multi_hat) ** 2)
    ss_tot = np.sum((y_multi - y_multi.mean()) ** 2)
    r2_multi = 1 - (ss_res / ss_tot)

    print("\nMultiple linear regression (standardized predictors):")
    print(f"Rows used: {len(multi_df)}")
    print(f"R^2: {r2_multi:.4f}")
    print(f"Intercept: {beta[0]:.4f}")
    for name, coef in zip(predictors, beta[1:]):
        print(f"Coefficient for {name}: {coef:.4f}")
else:
    print("\nSkipped multiple regression: not enough predictors or non-missing rows.")
# Out:
# Target variable used: DepressionRate_2023_x
# Rows used in simple regression: 41
# Simple model equation: DepressionRate_2023_x = 6142.7049 + (-62.1327) * sqm_mean
# Pearson r: -0.1613
# R^2: 0.0260
# Permutation-test p-value for slope (two-sided, 5000 shuffles): 0.3091
# Multiple linear regression (standardized predictors):
# Rows used: 41
# R^2: 0.0758
# Intercept: 4960.0005
# Coefficient for sqm_mean: -84.2451
# Coefficient for limiting_mag_mean: 61.5726
# Coefficient for light_obs_count: 122.0098

# %% [markdown]
# #### Analysis 1 Interpretation
#
# The first analysis suggests that states with darker average skies (`sqm_mean`) tend to have slightly lower depression rates, but the pattern is weak. On the plot, the trend line has the expected direction, yet many states are spread far from that line, which means sky brightness by itself does not predict depression very strongly.
#
# For our project, this is still an important result. It supports the idea that light pollution may be related to mental-health outcomes, but it also shows that depression rates are likely influenced by many other factors beyond nighttime brightness alone. Overall, Analysis 1 points to a small association rather than a strong statewide effect.

# %% [markdown]
# ## Second Data Analysis: Comparing Depression Rates Between Brighter and Darker Sky States
#
# To further explore the relationship between nighttime sky brightness and mental health, we divide states into two groups based on their sky brightness levels. States with darker skies are compared to states with brighter skies to examine whether there is a difference in average depression rates. This analysis uses a statistical comparison between the two groups to determine whether any observed difference is meaningful.

# %% [markdown]
# ### 2.1 Data Preparation and Grouping
#
# To compare depression rates between brighter and darker sky states, we first create a smaller dataframe containing the relevant variables (`limiting_mag_mean` and `DepressionRate_2023_x`). Missing values are removed to ensure valid comparisons.
#
# States are then divided into two groups based on the median value of sky brightness. States with sky brightness values greater than or equal to the median are classified as **darker-sky states**, while those below the median are classified as **brighter-sky states**.

# %%
# make a smaller dataframe with the variables we need
df = combined_df_3way[['limiting_mag_mean', 'DepressionRate_2023_x']].dropna()

# find the middle value of sky brightness
mid = df['limiting_mag_mean'].median()

# split states into two groups
dark_states = df[df['limiting_mag_mean'] >= mid]
bright_states = df[df['limiting_mag_mean'] < mid]

# %% [markdown]
# ### 2.2 Descriptive Statistics
#
# After splitting the states into brighter and darker sky groups, we compute descriptive statistics for the depression rates in each group. This includes the number of states, mean depression rate, standard deviation, and quartiles. These statistics help summarize the distribution of depression rates and allow us to observe any initial differences between the two groups.

# %%
print("darker sky states:", len(dark_states))
print("brighter sky states:", len(bright_states))

print("Average depression (dark skies):",
      dark_states['DepressionRate_2023_x'].mean())

print("Average depression (bright skies):",
      bright_states['DepressionRate_2023_x'].mean())

print("Dark sky states:")
print(dark_states['DepressionRate_2023_x'].describe())

print("\nBright sky states:")
print(bright_states['DepressionRate_2023_x'].describe())
# Out:
# darker sky states: 26
# brighter sky states: 25
# Average depression (dark skies): 4941.245
# Average depression (bright skies): 4871.7660000000005
# Dark sky states:
# count      26.000000
# mean     4941.245000
# std       595.992602
# min      3713.870000
# 25%      4572.470000
# 50%      4908.120000
# 75%      5341.077500
# max      6299.280000
# Name: DepressionRate_2023_x, dtype: float64
#
# Bright sky states:
# count      25.000000
# mean     4871.766000
# std       641.999044
# min      3582.770000
# 25%      4471.660000
# 50%      4892.510000
# 75%      5297.190000
# max      6060.950000
# Name: DepressionRate_2023_x, dtype: float64

# %% [markdown]
# ### 2.3 Visualization of Group Differences

# %%
plt.figure(figsize=(8,6))

sns.boxplot(
    data=df,
    x=(df['limiting_mag_mean'] >= mid),
    y='DepressionRate_2023_x'
)

plt.xticks([0,1], ["Brighter skies", "Darker skies"])
plt.title("Depression Rates: Brighter vs Darker Sky States")
plt.xlabel("Sky Brightness Group")
plt.ylabel("Depression Rate (per 100,000 people)")

plt.show()

# %% [markdown]
# ### Interpretation of the Boxplot
#
# The boxplot compares the distribution of depression rates between states with brighter skies and with darker skies. We see that both the groups show similar spread of depression rates with substantial overlap between their distributions. The median depression rate appears slightly higher for darker-sky states compared to brighter-sky states but the difference is relatively small. Additionally the interquartile ranges for both groups are similar indicating that the variability of depression rates is comparable between brighter and darker sky states. The large overlap between the boxes and whiskers suggests that sky brightness alone may not strongly differentiate depression rates across states.
#
# Overall while darker-sky states show a slightly higher median depression rate the visual evidence indicates that the relationship between sky brightness and depression rates is weak at the state level.

# %% [markdown]
# ### Conclusion
#
# Overall the analysis suggests that states with darker skies have a slightly higher average depression rate than states with brighter skies. However difference between the two groups is relatively small and distributions overlap considerably and this indicates that sky brightness alone does not appear to strongly explain differences in depression rates across states.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# Even though this study is only looking at correlations between nighttime light exposure and mental-health data I think there is a risk of misunderstanding the results as direct cause-and-effect. For example the city planners might reduce lighting too aggressively without thinking about safety, transportation visibility, or nighttime business activity. There is also a chance that states or regions with higher reported depression or anxiety rates could become stigmatized or be unfairly judged. Mental health is influenced by many different social and economic factors and so focusing only on light pollution is oversimplifying a much bigger issue. To avoid this, the study will explain clearly its limitations and emphasize that the findings show associations and not definite causes.
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > We are diving into the topic of mental health, so it is important to have their consent to use datasets in regards to their mental health symptoms, such as whether they have depression. We will ensure that the datasets we use note that the participants were consenting.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
#  > While we are not personally collecting the data, we are gathering it amongst various public datasets. We will try to find datasets that have a diverse variety of participants to minimize bias.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  > We will not be using any personally identifiable information such as name, but will instead be using datasets that have been anonymized
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
#  > As we look at the relationship between light pollution and mental health, we may find a relationship that actually represents race or culture. We will try to reduce bias for these by taking into consideration the distribution of race and the light pollution distribution.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  > If we have any private or personal information, data security is very important. However, we are using publicly available datasets, without people’s personal information.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
#  > Any person should have the right to remove their personal information. We are using a public dataset, so we will likely not have their personal information in the first place.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
#  > We can delete the data on people’s mental health after analysing the features for our research question. There is no need to hold on to the data.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
#  > We should consider the relevant groups’ perspectives during analysis, such as people who have mental health symptoms including depression, climate change or weather related scientists, and possibly therapists who work with people with depression.
#
# - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
#  > To reduce bias, we plan to take any variables that are not relevant to our question out of our data relationship calculations, including variables such as race, gender, class, etc.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
#  > There are many ways to manipulate how the same data looks through visualization such as changing the axis on a graph, so we will take steps to ensure that we are not purposefully doing that in order to showcase the data impartially.
#
# - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
#  > We will eliminate any PII from our dataset to prevent it from becoming a problem in the first place. This way we will not accidently reveal anyone’s personal information.
#
# - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#  > This is important for those who want to replicate or improve this data analysis and research question. Throughout this process, we will try to document our process, as well as check over the documentation at the end to ensure that it is understandable and clearly communicates what we have done.
#
# ### D. Modeling
# - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
#  > We plan to verify that the model does not rely on variables that are unfairly discriminatory. We aspire for our data to analyze people of all backgrounds and cultures and how depression of large, diverse groups from different areas of the United States are affected by varying light pollution.
#
# - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
#  > We will consider the effects of optimizing for our defined metrics possibility to include trade-offs like bias, overfitting, and unequal subgroup performance so we plan to monitor other metrics like fairness and error distributions to verify improvements reflected real, responsible model performance.
#
# - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
#  > Yes, many of our members have had experience describing technical outcomes or phenomena in more understandable terms to be more friendly and accessible by viewers of all backgrounds and understandings of data science.
#
# - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
#  > We plan to communicate the flaws, shortcomings, and limitations of the model to be transparent with our work. We want to be completely open in regards to the benefits our project has and what it does well while still noting the parts that
#
# ### E. Deployment
# - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
#  > Yes, we can implement a response process where potential harms are reviewed. Cases would be analyzed by the team and insights are used to update data, metrics, model, etc. to reduce risk of future harm.
#
# - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
#  > Is there a way to turn off or roll back the model in production if necessary?
# The goal would be to include an ability to shut off or pull back the model if issues arise to safely and efficiently revert to a safer version of the model.
#
# - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
#  > We hope to consider unintended uses and abuses of the model by implementing constraints and documentation to limit misuse and consistent monitoring to detect it if it happens in the future post-deployment.

# %% [markdown]
# ## Discussion
# This study set out to examine whether state-level light pollution is meaningfully associated with depression rates across the United States. Using sky brightness data from Globe at Night 2024 alongside state-aggregated depression prevalence statistics, we applied linear regression, permutation testing, and a multiple regression model incorporating three light pollution indicators (SQM mean, limiting magnitude mean, and light observation count) to quantify any relationship. The core finding is that while states with darker skies show a slight tendency toward lower depression rates, the association is weak, with an R² of approximately 0.08 and modest correlations between light pollution variables and depression outcomes (r ≈ −0.09 to −0.16). The permutation test further confirmed that these associations are not substantially stronger than what chance alone might produce.
#
# These results are consistent with broader scientific literature in some respects but fall short of confirming its stronger claims. Prior research at the individual and clinical level has suggested that artificial light at night can disrupt circadian rhythms, suppress melatonin production, and contribute to mood dysregulation—mechanisms that plausibly link chronic light exposure to depressive outcomes. Our analysis does not contradict that biological story, but it does suggest that when data are aggregated at the state level, the signal becomes too diffused to detect with confidence. States are large, heterogeneous units, and averaging sky brightness observations across an entire state obscures enormous within-state variation in both light exposure and mental health outcomes.
#
# Taken together, the various analyses point in a consistent direction: light pollution may be a small contributing factor in population-level mental health trends, but it is far from a dominant one. The correlation matrix, the low $R^2$, and the overlapping distributions in the group comparisons all reinforce each other. This coherence is actually informative, suggesting that the null result is not simply an artifact of one flawed analysis, but a genuine reflection of the weak relationship at this level of aggregation. The bigger picture is that depression is a multifactorial condition shaped by economic stress, healthcare access, social connectedness, climate, and dozens of other variables that a single environmental measure cannot capture.
#
# ## Conclusion
#
# ### Summary
# The primary objective of this study was to determine if a measurable relationship exists between state-level light pollution and the prevalence of depression across the United States. We hypothesized that higher levels of artificial light at night would correlate with higher rates of diagnosed depression. To test this, we merged citizen-science sky brightness observations with 2023 public health statistics. Our analysis found a statistically significant but weak negative correlation between the mean limiting magnitude of the night sky and state-level depression rates. In our final visualizations, the regression line shows a clear downward slope; because a lower limiting magnitude on the Globe at Night scale represents brighter, more light-polluted skies, this downward trend indicates that as light pollution increases, depression prevalence tends to rise as well. While the weak nature of the correlation suggests that light pollution is only one of many complex variables influencing mental health, the fact that the trend is statistically significant provides critical support for our original hypothesis.
#
# ### Limitations and Ethical Considerations
# It is important to acknowledge that our data is cross asectional, representing a snapshot in time rather than a longitudinal study that could definitively prove a causal link. Additionally, the Globe at Night dataset relies on volunteer observations, which introduces a sampling bias as some states have much higher participation than others. Ethically, we must also consider diagnostic bias, meaning brighter, more urbanized states often have more robust medical infrastructure. This could lead to higher reported depression rates simply because people in those areas have better access to healthcare providers, rather than purely because of the light exposure.
#
# ### Next Steps and Future Direction
# If this investigation were to continue, the logical next step would be to utilize high resolution satellite derived data to eliminate the sampling bias of citizen science observations. Also, moving the analysis from a state level to a county or city level in the United States would allow for a much more precise look at how specific light pollution hotspots impact local populations. Integrating control variables like median income and population density would also help isolate the specific psychological impact of light pollution from the general stresses of urban living. Ultimately, this project highlights the importance of dark sky initiatives as a potential factor in promoting public mental well being across the United States.
